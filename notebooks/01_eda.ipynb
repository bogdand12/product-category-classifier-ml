# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
df = pd.read_csv('../data/products.csv')
df.head()

# %%
df.info()

# %%
df.isnull().sum()

# %%
df[' Category Label'].value_counts().head(20)
