# %% [markdown]
# # 01 - Exploratory Data Analysis
#
# Objective: understand dataset structure and quality.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/products.csv')
df.head()

# %% [markdown]
# ## Dataset Overview

# %%
df.info()

# %%
df.isnull().sum()

# %% [markdown]
# ## Category Distribution

# %%
df['Category Label'].value_counts().head(20)

# %%
df['title_length']=df['Product Title'].astype(str).apply(len)
df['title_length'].describe()

# %% [markdown]
# ## Conclusions
# - Dataset suitable for NLP classification.
# - Product titles contain most predictive information.
